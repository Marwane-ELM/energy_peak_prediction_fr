# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
import os
import re
sys.path.append(os.path.abspath(".."))
import src.dataset_selection as ds
import src.model_selection as md
import mlflow
import pandas as pd
import numpy as np

# %% [markdown]
# ### Training all the models on all the datasets

# %%
ds.log_models(
    '../data/final_datasets/datasets_linear_models',
    '../data/final_datasets/datasets_tree_based_models'
)
# Out:
# 🏃 View run LinearRegression_conso_v2_linear at: http://localhost:5000/#/experiments/2/runs/3550bea284334b69b4ad4869160d88cd
# 🧪 View experiment at: http://localhost:5000/#/experiments/2
# 🏃 View run Lasso_conso_v2_linear at: http://localhost:5000/#/experiments/2/runs/f5fca5a286864216b448c78974954dbb
# 🧪 View experiment at: http://localhost:5000/#/experiments/2
# 🏃 View run Ridge_conso_v2_linear at: http://localhost:5000/#/experiments/2/runs/b2ae30e3be174be09535e24c9d40cb9e
# 🧪 View experiment at: http://localhost:5000/#/experiments/2
# 🏃 View run ElasticNet_conso_v2_linear at: http://localhost:5000/#/experiments/2/runs/f0d621bdca3049309130525f2fad8e1b
# 🧪 View experiment at: http://localhost:5000/#/experiments/2
# 🏃 View run LinearRegression_conso_v3_linear at: http://localhost:5000/#/experiments/2/runs/617590fb52434db3b5b2012294eee47c
# 🧪 View experiment at: http://localhost:5000/#/experiments/2
# 🏃 View run Lasso_conso_v3_linear at: http://localhost:5000/#/experiments/2/runs/9313d4873c9a4597a59403352a3ddbda
# 🧪 View experiment at: http://localhost:5000/#/experiments/2
# 🏃 View run Ridge_conso_v3_linear at: http://localhost:5000/#/experiments/2/runs/a5330be4f4c740b8826622b8a8418a32
# 🧪 View experiment at: http://localhost:5000/#/experiments/2
# 🏃 View run ElasticNet_conso_v3_linear at: http://localhost:5000/#/experiments/2/runs/474e853cc6a846548f3489c6487e0675
# 🧪 View experiment at: http://localhost:5000/#/experiments/2
# 🏃 View run LinearRegression_conso_v1_linear at: http://localhost:5000/#/experiments/2/runs/60672c9789f146c0a730355258d4ec2f
# 🧪 View experiment at: http://localhost:5000/#/experiments/2
# 🏃 View run Lasso_conso_v1_linear at: http://localhost:5000/#/experiments/2/runs/03c3d42c416440c5938368208cea2cdd
# 🧪 View experiment at: http://localhost:5000/#/experiments/2
# 🏃 View run Ridge_conso_v1_linear at: http://localhost:5000/#/experiments/2/runs/c2714d13f8444858a39a5d93b4152905
# 🧪 View experiment at: http://localhost:5000/#/experiments/2
# 🏃 View run ElasticNet_conso_v1_linear at: http://localhost:5000/#/experiments/2/runs/63f05e88d8b042a88c134560338b2d72
# 🧪 View experiment at: http://localhost:5000/#/experiments/2
# Linear Experiment successfully saved
# 🏃 View run GradientBoostingRegressor_conso_v2_tree at: http://localhost:5000/#/experiments/3/runs/d2fb33bedcd64d36878f632da3856105
# 🧪 View experiment at: http://localhost:5000/#/experiments/3
# 🏃 View run HistGradientBoostingRegressor_conso_v2_tree at: http://localhost:5000/#/experiments/3/runs/3acedb6e079846bab5131caf998cc30e
# 🧪 View experiment at: http://localhost:5000/#/experiments/3
# 🏃 View run RandomForestRegressor_conso_v2_tree at: http://localhost:5000/#/experiments/3/runs/d6be3da96c4540c0858db526358c82d7
# 🧪 View experiment at: http://localhost:5000/#/experiments/3
# 🏃 View run GradientBoostingRegressor_conso_v3_tree at: http://localhost:5000/#/experiments/3/runs/cc0ade3bd2ca4888aa33c6cd60e46dde
# 🧪 View experiment at: http://localhost:5000/#/experiments/3
# 🏃 View run HistGradientBoostingRegressor_conso_v3_tree at: http://localhost:5000/#/experiments/3/runs/bb8f738904334e4991b2dff7b816e2b0
# 🧪 View experiment at: http://localhost:5000/#/experiments/3
# 🏃 View run RandomForestRegressor_conso_v3_tree at: http://localhost:5000/#/experiments/3/runs/cee39c653fb642f9b74cef31b525d02f
# 🧪 View experiment at: http://localhost:5000/#/experiments/3
# 🏃 View run GradientBoostingRegressor_conso_v1_tree at: http://localhost:5000/#/experiments/3/runs/b89696214f384486b408e423e926ad9c
# 🧪 View experiment at: http://localhost:5000/#/experiments/3
# 🏃 View run HistGradientBoostingRegressor_conso_v1_tree at: http://localhost:5000/#/experiments/3/runs/cb59edcc250645d388e982e565d502f8
# 🧪 View experiment at: http://localhost:5000/#/experiments/3
# 🏃 View run RandomForestRegressor_conso_v1_tree at: http://localhost:5000/#/experiments/3/runs/c553f512417947158fd93f02c672fc70
# 🧪 View experiment at: http://localhost:5000/#/experiments/3
# Trees Experiment successfully saved

# %% [markdown]
# After the analysis of the results, we'll keep the **dataset v3** because this one contains the best number of columns about the temperatures of the different French departments. Hence, it reduces the numner of dimensions and reduces overfitting too.
# More over, we'll focus on **Ridge** (resists to overfitting on new data) and **HistGradientBoostingRegressor** (faster than a Random Forest during the training)

# %% [markdown]
# ### Training in depth the 2 best models

# %%
from sklearn.linear_model import Ridge
from sklearn.ensemble import HistGradientBoostingRegressor

# %%
md.launch_training(
    '../data/final_datasets/datasets_linear_models/conso_v3_linear.parquet',
    '../data/final_datasets/datasets_tree_based_models/conso_v3_tree.parquet',
    Ridge(),
    HistGradientBoostingRegressor(),
    np.arange(0, 10, 1)    
)
# Out:
# 2026/06/27 17:35:03 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 🏃 View run Ridge_conso_v3_linear_horizon_0 at: http://localhost:5000/#/experiments/4/runs/a854f4765c694dac8453a3a9b526f86b
# 🧪 View experiment at: http://localhost:5000/#/experiments/4
# 2026/06/27 17:35:18 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 🏃 View run Ridge_conso_v3_linear_horizon_1 at: http://localhost:5000/#/experiments/4/runs/055ab38270c747878755051fd553e5d8
# 🧪 View experiment at: http://localhost:5000/#/experiments/4
# 2026/06/27 17:35:33 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 🏃 View run Ridge_conso_v3_linear_horizon_2 at: http://localhost:5000/#/experiments/4/runs/9a049db67eaa468faa4cab0c92b4303a
# 🧪 View experiment at: http://localhost:5000/#/experiments/4
# 2026/06/27 17:35:48 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 🏃 View run Ridge_conso_v3_linear_horizon_3 at: http://localhost:5000/#/experiments/4/runs/0f43005836234878b188425003ab0904
# 🧪 View experiment at: http://localhost:5000/#/experiments/4
# 2026/06/27 17:36:02 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 🏃 View run Ridge_conso_v3_linear_horizon_4 at: http://localhost:5000/#/experiments/4/runs/91fd32e3c5614c6ca53e04bd0fbd2b6e
# 🧪 View experiment at: http://localhost:5000/#/experiments/4
# 2026/06/27 17:36:17 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 🏃 View run Ridge_conso_v3_linear_horizon_5 at: http://localhost:5000/#/experiments/4/runs/01ab6286bf4e494b967046d8cab7d59b
# 🧪 View experiment at: http://localhost:5000/#/experiments/4
# 2026/06/27 17:36:31 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 🏃 View run Ridge_conso_v3_linear_horizon_6 at: http://localhost:5000/#/experiments/4/runs/6ff4fa056af24fcaab5e3357f981f44e
# 🧪 View experiment at: http://localhost:5000/#/experiments/4
# 2026/06/27 17:36:46 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 🏃 View run Ridge_conso_v3_linear_horizon_7 at: http://localhost:5000/#/experiments/4/runs/f806be7a51f24fa2adbe6fec9f6390d5
# 🧪 View experiment at: http://localhost:5000/#/experiments/4
# 2026/06/27 17:37:00 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 🏃 View run Ridge_conso_v3_linear_horizon_8 at: http://localhost:5000/#/experiments/4/runs/4ed36e712eb14fcfaf09e2991de0d140
# 🧪 View experiment at: http://localhost:5000/#/experiments/4
# 2026/06/27 17:37:15 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 🏃 View run Ridge_conso_v3_linear_horizon_9 at: http://localhost:5000/#/experiments/4/runs/3ba37f8482cf493f8c88c70852ff0077
# 🧪 View experiment at: http://localhost:5000/#/experiments/4
# Best models Experiment successfully saved
# 2026/06/27 17:38:50 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 🏃 View run HistGradientBoostingRegressor_conso_v3_tree_horizon_0 at: http://localhost:5000/#/experiments/4/runs/2a60e39f74fa443fac7990a8bdab696e
# 🧪 View experiment at: http://localhost:5000/#/experiments/4
# 2026/06/27 17:40:23 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 🏃 View run HistGradientBoostingRegressor_conso_v3_tree_horizon_1 at: http://localhost:5000/#/experiments/4/runs/707320d65fdf46bcbb7d806bbdd49311
# 🧪 View experiment at: http://localhost:5000/#/experiments/4
# 2026/06/27 17:41:57 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 🏃 View run HistGradientBoostingRegressor_conso_v3_tree_horizon_2 at: http://localhost:5000/#/experiments/4/runs/e0795be2bb3b46f3bc2e921002ee9672
# 🧪 View experiment at: http://localhost:5000/#/experiments/4
# 2026/06/27 17:43:32 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 🏃 View run HistGradientBoostingRegressor_conso_v3_tree_horizon_3 at: http://localhost:5000/#/experiments/4/runs/d4e501d3d2164d6d9d20053cefa6f92a
# 🧪 View experiment at: http://localhost:5000/#/experiments/4
# 2026/06/27 17:45:12 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 🏃 View run HistGradientBoostingRegressor_conso_v3_tree_horizon_4 at: http://localhost:5000/#/experiments/4/runs/767d1cdd525c44a281ffe5d6d3025463
# 🧪 View experiment at: http://localhost:5000/#/experiments/4
# 2026/06/27 17:46:47 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 🏃 View run HistGradientBoostingRegressor_conso_v3_tree_horizon_5 at: http://localhost:5000/#/experiments/4/runs/b4125c3ae7e04b69be7ba57a046f5ec9
# 🧪 View experiment at: http://localhost:5000/#/experiments/4
# 2026/06/27 17:48:22 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 🏃 View run HistGradientBoostingRegressor_conso_v3_tree_horizon_6 at: http://localhost:5000/#/experiments/4/runs/6109de0a255342cea95411034c97dbbc
# 🧪 View experiment at: http://localhost:5000/#/experiments/4
# 2026/06/27 17:49:57 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 🏃 View run HistGradientBoostingRegressor_conso_v3_tree_horizon_7 at: http://localhost:5000/#/experiments/4/runs/2d1fe06854924d8eb7799091ed0285a5
# 🧪 View experiment at: http://localhost:5000/#/experiments/4
# 2026/06/27 17:51:33 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 🏃 View run HistGradientBoostingRegressor_conso_v3_tree_horizon_8 at: http://localhost:5000/#/experiments/4/runs/e7ad937d1e9e46949c4f9a8ae5b580ef
# 🧪 View experiment at: http://localhost:5000/#/experiments/4
# 2026/06/27 17:53:09 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 🏃 View run HistGradientBoostingRegressor_conso_v3_tree_horizon_9 at: http://localhost:5000/#/experiments/4/runs/59f279959de54fe88d29b5e51035b791
# 🧪 View experiment at: http://localhost:5000/#/experiments/4
# Best models Experiment successfully saved

# %%
experiment_name = "Best models Experiment"
best_estimator, dict_models = md.dump_model_from_mlflow(
    experiment_name, 
    "../artifacts/model_artifacts"
)
# Out:
# Ridge models have been successfully saved in ../artifacts/model_artifacts/Ridge_2026-06-28_17-02-54
