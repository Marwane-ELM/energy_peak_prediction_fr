# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
import os
sys.path.append(os.path.abspath(".."))
import src.dataset_selection as ds
import src.model_selection as md
import mlflow
import numpy as np

# %% [markdown]
# ### Training all the models on all the datasets

# %%
ds.log_models(
    '../data/final_datasets/datasets_linear_models',
    '../data/final_datasets/datasets_tree_based_models'
)
# Out:
# 🏃 View run LinearRegression_conso_v2_linear at: http://localhost:5000/#/experiments/2/runs/3550bea284334b69b4ad4869160d88cd
# 🧪 View experiment at: http://localhost:5000/#/experiments/2
# 🏃 View run Lasso_conso_v2_linear at: http://localhost:5000/#/experiments/2/runs/f5fca5a286864216b448c78974954dbb
# 🧪 View experiment at: http://localhost:5000/#/experiments/2
# 🏃 View run Ridge_conso_v2_linear at: http://localhost:5000/#/experiments/2/runs/b2ae30e3be174be09535e24c9d40cb9e
# 🧪 View experiment at: http://localhost:5000/#/experiments/2
# 🏃 View run ElasticNet_conso_v2_linear at: http://localhost:5000/#/experiments/2/runs/f0d621bdca3049309130525f2fad8e1b
# 🧪 View experiment at: http://localhost:5000/#/experiments/2
# 🏃 View run LinearRegression_conso_v3_linear at: http://localhost:5000/#/experiments/2/runs/617590fb52434db3b5b2012294eee47c
# 🧪 View experiment at: http://localhost:5000/#/experiments/2
# 🏃 View run Lasso_conso_v3_linear at: http://localhost:5000/#/experiments/2/runs/9313d4873c9a4597a59403352a3ddbda
# 🧪 View experiment at: http://localhost:5000/#/experiments/2
# 🏃 View run Ridge_conso_v3_linear at: http://localhost:5000/#/experiments/2/runs/a5330be4f4c740b8826622b8a8418a32
# 🧪 View experiment at: http://localhost:5000/#/experiments/2
# 🏃 View run ElasticNet_conso_v3_linear at: http://localhost:5000/#/experiments/2/runs/474e853cc6a846548f3489c6487e0675
# 🧪 View experiment at: http://localhost:5000/#/experiments/2
# 🏃 View run LinearRegression_conso_v1_linear at: http://localhost:5000/#/experiments/2/runs/60672c9789f146c0a730355258d4ec2f
# 🧪 View experiment at: http://localhost:5000/#/experiments/2
# 🏃 View run Lasso_conso_v1_linear at: http://localhost:5000/#/experiments/2/runs/03c3d42c416440c5938368208cea2cdd
# 🧪 View experiment at: http://localhost:5000/#/experiments/2
# 🏃 View run Ridge_conso_v1_linear at: http://localhost:5000/#/experiments/2/runs/c2714d13f8444858a39a5d93b4152905
# 🧪 View experiment at: http://localhost:5000/#/experiments/2
# 🏃 View run ElasticNet_conso_v1_linear at: http://localhost:5000/#/experiments/2/runs/63f05e88d8b042a88c134560338b2d72
# 🧪 View experiment at: http://localhost:5000/#/experiments/2
# Linear Experiment successfully saved
# 🏃 View run GradientBoostingRegressor_conso_v2_tree at: http://localhost:5000/#/experiments/3/runs/d2fb33bedcd64d36878f632da3856105
# 🧪 View experiment at: http://localhost:5000/#/experiments/3
# 🏃 View run HistGradientBoostingRegressor_conso_v2_tree at: http://localhost:5000/#/experiments/3/runs/3acedb6e079846bab5131caf998cc30e
# 🧪 View experiment at: http://localhost:5000/#/experiments/3
# 🏃 View run RandomForestRegressor_conso_v2_tree at: http://localhost:5000/#/experiments/3/runs/d6be3da96c4540c0858db526358c82d7
# 🧪 View experiment at: http://localhost:5000/#/experiments/3
# 🏃 View run GradientBoostingRegressor_conso_v3_tree at: http://localhost:5000/#/experiments/3/runs/cc0ade3bd2ca4888aa33c6cd60e46dde
# 🧪 View experiment at: http://localhost:5000/#/experiments/3
# 🏃 View run HistGradientBoostingRegressor_conso_v3_tree at: http://localhost:5000/#/experiments/3/runs/bb8f738904334e4991b2dff7b816e2b0
# 🧪 View experiment at: http://localhost:5000/#/experiments/3
# 🏃 View run RandomForestRegressor_conso_v3_tree at: http://localhost:5000/#/experiments/3/runs/cee39c653fb642f9b74cef31b525d02f
# 🧪 View experiment at: http://localhost:5000/#/experiments/3
# 🏃 View run GradientBoostingRegressor_conso_v1_tree at: http://localhost:5000/#/experiments/3/runs/b89696214f384486b408e423e926ad9c
# 🧪 View experiment at: http://localhost:5000/#/experiments/3
# 🏃 View run HistGradientBoostingRegressor_conso_v1_tree at: http://localhost:5000/#/experiments/3/runs/cb59edcc250645d388e982e565d502f8
# 🧪 View experiment at: http://localhost:5000/#/experiments/3
# 🏃 View run RandomForestRegressor_conso_v1_tree at: http://localhost:5000/#/experiments/3/runs/c553f512417947158fd93f02c672fc70
# 🧪 View experiment at: http://localhost:5000/#/experiments/3
# Trees Experiment successfully saved

# %% [markdown]
# After the analysis of the results on the mlflow webapp, we'll keep the **dataset v3** because this one contains the best number of columns about the temperatures of the different French departments. Hence, it reduces the numner of dimensions and reduces overfitting too.
# More over, we'll focus on **Ridge** (resists to overfitting on new data) and **HistGradientBoostingRegressor** (faster than a Random Forest during the training)

# %% [markdown]
# ### Training in depth the 2 best models

# %%
from sklearn.linear_model import Ridge
from sklearn.ensemble import HistGradientBoostingRegressor

# %%
md.launch_training(
    'Best models (without lagged features shifted)',
    '../data/final_datasets/datasets_linear_models/conso_v3_linear.parquet',
    '../data/final_datasets/datasets_tree_based_models/conso_v3_tree.parquet',
    Ridge(),
    HistGradientBoostingRegressor(),
    np.arange(0, 10, 1)    
)
# Out:
# 2026/07/16 16:39:12 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 🏃 View run Ridge_conso_v3_linear_horizon_0 at: http://localhost:5000/#/experiments/5/runs/b4dacdae54da487d89e9079de0f79494
# 🧪 View experiment at: http://localhost:5000/#/experiments/5
# 2026/07/16 16:39:28 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 🏃 View run Ridge_conso_v3_linear_horizon_1 at: http://localhost:5000/#/experiments/5/runs/2ca7eb1d603b41d8a42f547be4d594db
# 🧪 View experiment at: http://localhost:5000/#/experiments/5
# 2026/07/16 16:39:43 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 🏃 View run Ridge_conso_v3_linear_horizon_2 at: http://localhost:5000/#/experiments/5/runs/3d6cbb0107804c29b61bebcb93a2aced
# 🧪 View experiment at: http://localhost:5000/#/experiments/5
# 2026/07/16 16:39:58 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 🏃 View run Ridge_conso_v3_linear_horizon_3 at: http://localhost:5000/#/experiments/5/runs/c8527978954b4ff29d70adb69309e371
# 🧪 View experiment at: http://localhost:5000/#/experiments/5
# 2026/07/16 16:40:13 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 🏃 View run Ridge_conso_v3_linear_horizon_4 at: http://localhost:5000/#/experiments/5/runs/29b385a1593940008295ef70369bf452
# 🧪 View experiment at: http://localhost:5000/#/experiments/5
# 2026/07/16 16:40:28 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 🏃 View run Ridge_conso_v3_linear_horizon_5 at: http://localhost:5000/#/experiments/5/runs/e150f9e3c5a54adc836cffa758aa59ef
# 🧪 View experiment at: http://localhost:5000/#/experiments/5
# 2026/07/16 16:40:43 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 🏃 View run Ridge_conso_v3_linear_horizon_6 at: http://localhost:5000/#/experiments/5/runs/00c7d627671244cbae5d745b33ea9e65
# 🧪 View experiment at: http://localhost:5000/#/experiments/5
# 2026/07/16 16:40:58 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 🏃 View run Ridge_conso_v3_linear_horizon_7 at: http://localhost:5000/#/experiments/5/runs/1e9b4ce68a9e4a4b924929c267d4f141
# 🧪 View experiment at: http://localhost:5000/#/experiments/5
# 2026/07/16 16:41:13 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 🏃 View run Ridge_conso_v3_linear_horizon_8 at: http://localhost:5000/#/experiments/5/runs/087d4ddf627c4111bcbceac887cf5db3
# 🧪 View experiment at: http://localhost:5000/#/experiments/5
# 2026/07/16 16:41:29 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 🏃 View run Ridge_conso_v3_linear_horizon_9 at: http://localhost:5000/#/experiments/5/runs/cff3183885b043b095547673a7d04a82
# 🧪 View experiment at: http://localhost:5000/#/experiments/5
# Best models (without lagged features shifted) successfully saved
# 2026/07/16 16:43:01 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 🏃 View run HistGradientBoostingRegressor_conso_v3_tree_horizon_0 at: http://localhost:5000/#/experiments/5/runs/b21549bab54245c381b0b7fa3e10da6b
# 🧪 View experiment at: http://localhost:5000/#/experiments/5
# 2026/07/16 16:44:31 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 🏃 View run HistGradientBoostingRegressor_conso_v3_tree_horizon_1 at: http://localhost:5000/#/experiments/5/runs/7bf388d7c11345b4a5da8350714ce802
# 🧪 View experiment at: http://localhost:5000/#/experiments/5
# 2026/07/16 16:45:59 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 🏃 View run HistGradientBoostingRegressor_conso_v3_tree_horizon_2 at: http://localhost:5000/#/experiments/5/runs/18b2d55f15d9418484b361450b085cfb
# 🧪 View experiment at: http://localhost:5000/#/experiments/5
# 2026/07/16 16:47:26 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 🏃 View run HistGradientBoostingRegressor_conso_v3_tree_horizon_3 at: http://localhost:5000/#/experiments/5/runs/96eba0def5f44d988610955f1377c29f
# 🧪 View experiment at: http://localhost:5000/#/experiments/5
# 2026/07/16 16:48:52 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 🏃 View run HistGradientBoostingRegressor_conso_v3_tree_horizon_4 at: http://localhost:5000/#/experiments/5/runs/54c9abb45a654665a6082aebda7bf5f2
# 🧪 View experiment at: http://localhost:5000/#/experiments/5
# 2026/07/16 16:50:19 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 🏃 View run HistGradientBoostingRegressor_conso_v3_tree_horizon_5 at: http://localhost:5000/#/experiments/5/runs/f2fa4e84dc444806b7fdf7c04816f01e
# 🧪 View experiment at: http://localhost:5000/#/experiments/5
# 2026/07/16 16:51:44 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 🏃 View run HistGradientBoostingRegressor_conso_v3_tree_horizon_6 at: http://localhost:5000/#/experiments/5/runs/5f6d9659893448a39c78ecebf4143754
# 🧪 View experiment at: http://localhost:5000/#/experiments/5
# 2026/07/16 16:53:10 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 🏃 View run HistGradientBoostingRegressor_conso_v3_tree_horizon_7 at: http://localhost:5000/#/experiments/5/runs/5c193158b6c240fb8f0aef41582e7616
# 🧪 View experiment at: http://localhost:5000/#/experiments/5
# 2026/07/16 16:54:35 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 🏃 View run HistGradientBoostingRegressor_conso_v3_tree_horizon_8 at: http://localhost:5000/#/experiments/5/runs/6dbe09d8c09b468bb90c039aacd06459
# 🧪 View experiment at: http://localhost:5000/#/experiments/5
# 2026/07/16 16:56:00 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 🏃 View run HistGradientBoostingRegressor_conso_v3_tree_horizon_9 at: http://localhost:5000/#/experiments/5/runs/e1f2e1b5719d4d479677c1e044019b92
# 🧪 View experiment at: http://localhost:5000/#/experiments/5
# Best models (without lagged features shifted) successfully saved

# %%
experiment_name = "Best models (without lagged features shifted)"
best_estimator, dict_models = md.dump_model_from_mlflow(
    experiment_name, 
    "../artifacts/model_artifacts"
)
# Out:
# Ridge models have been successfully saved in ../artifacts/model_artifacts/Ridge_2026-07-16_16-58-27
