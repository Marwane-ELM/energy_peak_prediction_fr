# %%
# %load_ext autoreload
# %autoreload 2

# %%
from pathlib import Path
import os
import sys
sys.path.append(os.path.abspath(".."))

import pandas as pd
import numpy as np
import src.create_dataset as cd
from datetime import datetime
import requests

# %%
pd.read_parquet("../data/weather/clean_weather/H_13_previous-2020-2024.parquet")
# Out:
#              Date    Heures  NUM_POSTE     LAT     LON     T     U   FF  \
# 0      2021-01-01  00:00:00   13054001  43.437  5.2115  7.60  87.0  7.2
# 1      2021-01-01  00:30:00   13054001  43.437  5.2115  7.80  86.0  3.7
# 2      2021-01-01  01:00:00   13054001  43.437  5.2115  8.00  85.0  7.1
# 3      2021-01-01  01:30:00   13054001  43.437  5.2115  8.25  83.0  3.7
# 4      2021-01-01  02:00:00   13054001  43.437  5.2115  8.50  81.0  5.9
# ...           ...       ...        ...     ...     ...   ...   ...  ...
# 70123  2024-12-31  21:30:00   13054001  43.437  5.2115  5.95  90.5  3.7
# 70124  2024-12-31  22:00:00   13054001  43.437  5.2115  5.70  91.0  1.0
# 70125  2024-12-31  22:30:00   13054001  43.437  5.2115  5.50  92.0  3.7
# 70126  2024-12-31  23:00:00   13054001  43.437  5.2115  5.30  93.0  0.5
# 70127  2024-12-31  23:30:00   13054001  43.437  5.2115  5.30  93.0  3.7
#
#           PMER  RR1
# 0      1005.50  0.4
# 1      1005.20  0.0
# 2      1004.90  0.0
# ...

# %%
cd.final_dataset()
# Out:
# Do you want to create 3 dataset versions (type 'yes' or 'no')) :  yes
# ...
# conso_energie_2024.zip already exists
# conso_energie_2023.zip already exists
# conso_energie_2022.zip already exists
# conso_energie_2021.zip already exists
# calendrier_gouv.parquet already exists
# jours_feries_metropole.csv already exists
# H_13_previous-2020-2024.csv.gz already exists
# H_21_previous-2020-2024.csv.gz already exists
# H_31_previous-2020-2024.csv.gz already exists
# H_33_previous-2020-2024.csv.gz already exists
# H_35_previous-2020-2024.csv.gz already exists
# H_44_previous-2020-2024.csv.gz already exists
# H_45_previous-2020-2024.csv.gz already exists
# H_59_previous-2020-2024.csv.gz already exists
# H_67_previous-2020-2024.csv.gz already exists
# H_69_previous-2020-2024.csv.gz already exists
# H_75_previous-2020-2024.csv.gz already exists
# H_76_previous-2020-2024.csv.gz already exists
#
# Start of preprocessing part
# conso dataset succesfully loaded
# ...
