# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from pathlib import Path
import os
import sys
sys.path.append(os.path.abspath(".."))

import pandas as pd
import numpy as np
import src.create_dataset as cd
from datetime import datetime

# %%
linear_dataset, tree_dataset = cd.final_dataset()
# Out:
# Downloading the required datasets
# conso_energie_2024.zip already exists
# conso_energie_2023.zip already exists
# conso_energie_2022.zip already exists
# conso_energie_2021.zip already exists
# calendrier_gouv.parquet already exists
# jours_feries_metropole.csv already exists
# H_13_previous-2020-2024.csv.gz already exists
# H_33_previous-2020-2024.csv.gz already exists
# H_44_previous-2020-2024.csv.gz already exists
# H_59_previous-2020-2024.csv.gz already exists
# H_69_previous-2020-2024.csv.gz already exists
# H_75_previous-2020-2024.csv.gz already exists
#
# Start of preprocessing part
# /home/marwane/energy_peak_prediction/src/raw_preprocessing.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# conso dataset succesfully created
#
#
# Everything has been successfully saved in ../data/weather/clean_weather
#
#  Preprocessing completed successfully
#
# End of preprocessing part
#
#
# Start of feature engineering part
#
# The dataset ../data/final_datasets/datasets_versions has been successfully saved
# ../data/final_datasets/datasets_tree_based_models/conso_v3_tree.parquet and ../data/final_datasets/datasets_linear_models/conso_v3_linear.parquet already exist
#
# End of feature engineering part
# /home/marwane/energy_peak_prediction/src/raw_preprocessing.py:6: FutureWarning: The behavior of 'isin' with dtype=datetime64[ns] and castable values (e.g. strings) is deprecated. In a future version, these will not be considered matching by isin. Explicitly cast to the appropriate dtype before calling isin instead.
#   import re

# %%
linear_dataset
# Out:
#        Consommation  Zone_A  Zone_B  Zone_C  Vacances de la Toussaint  \
# 336         76986.0       0       0       0                         0
# 337         75624.0       0       0       0                         0
# 338         73317.0       0       0       0                         0
# 339         74096.0       0       0       0                         0
# 340         73854.0       0       0       0                         0
# ...             ...     ...     ...     ...                       ...
# 70123       63946.0       0       0       0                         0
# 70124       63063.0       0       0       0                         0
# 70125       63816.0       0       0       0                         0
# 70126       65437.0       0       0       0                         0
# 70127       65159.0       0       0       0                         0
#
#        Vacances de Noël  Vacances d'Hiver  Vacances de Printemps  \
# 336                   0                 0                      0
# 337                   0                 0                      0
# 338                   0                 0                      0
# 339                   0                 0                      0
# 340                   0                 0                      0
# ...                 ...               ...                    ...
# 70123                 0                 0                      0
# 70124                 0                 0                      0
# 70125                 0                 0                      0
# 70126                 0                 0                      0
# 70127                 0                 0                      0
#
#        Vacances d'Été  public_holidays  ...  is_weekend_x_season_Summer  \
# 336                 0                0  ...                           0
# 337                 0                0  ...                           0
# 338                 0                0  ...                           0
# 339                 0                0  ...                           0
# 340                 0                0  ...                           0
# ...               ...              ...  ...                         ...
# 70123               0                0  ...                           0
# 70124               0                0  ...                           0
# 70125               0                0  ...                           0
# 70126               0                0  ...                           0
# 70127               0                0  ...                           0
#
#        is_holiday_x_season_Summer  hour_x_season_Winter  \
# 336                             0                   0.0
# 337                             0                   0.5
# 338                             0                   1.0
# 339                             0                   1.5
# 340                             0                   2.0
# ...                           ...                   ...
# 70123                           0                  21.5
# 70124                           0                  22.0
# 70125                           0                  22.5
# 70126                           0                  23.0
# 70127                           0                  23.5
#
#        is_weekend_x_season_Winter  is_holiday_x_season_Winter  \
# 336                             0                           0
# 337                             0                           0
# 338                             0                           0
# 339                             0                           0
# 340                             0                           0
# ...                           ...                         ...
# 70123                           0                           0
# 70124                           0                           0
# 70125                           0                           0
# 70126                           0                           0
# 70127                           0                           0
#
#        temp_x_humidity  temp_x_wind  humidity_x_wind   HDD  CDD
# 336                0.0          0.0              0.0  18.0  0.0
# 337                0.0          0.0              0.0  18.0  0.0
# 338                0.0          0.0              0.0  18.0  0.0
# 339                0.0          0.0              0.0  18.0  0.0
# 340                0.0          0.0              0.0  18.0  0.0
# ...                ...          ...              ...   ...  ...
# 70123              0.0          0.0              0.0  18.0  0.0
# 70124              0.0          0.0              0.0  18.0  0.0
# 70125              0.0          0.0              0.0  18.0  0.0
# 70126              0.0          0.0              0.0  18.0  0.0
# 70127              0.0          0.0              0.0  18.0  0.0
#
# [69792 rows x 74 columns]
