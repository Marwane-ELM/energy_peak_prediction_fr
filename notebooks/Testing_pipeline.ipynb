# %%
# %load_ext autoreload
# %autoreload 2

# %%
from pathlib import Path
import os
import sys
sys.path.append(os.path.abspath(".."))

import pandas as pd
import numpy as np
import src.create_dataset as cd
from datetime import datetime

# %%
linear_dataset, tree_dataset = cd.final_dataset()
# Out:
# Start of preprocessing part
# conso dataset succesfully loaded
# The file for the department n°13 already exists
# The file for the department n°67 already exists
# The file for the department n°75 already exists
# The file for the department n°45 already exists
# The file for the department n°21 already exists
# The file for the department n°44 already exists
# The file for the department n°35 already exists
# The file for the department n°59 already exists
# The file for the department n°69 already exists
# The file for the department n°76 already exists
# The file for the department n°31 already exists
# The file for the department n°33 already exists
#
#
# Everything has been successfully saved in ../data/weather/clean_weather
#
#  Preprocessing completed successfully
#
# End of preprocessing part
#
#
# Start of feature engineering part
#
# The file ../data/final_datasets/datasets_versions/conso_v3.parquet already exists
# ...

# %%
linear_dataset
# Out:
#        Consommation  Zone_A  Zone_B  Zone_C  Vacances de la Toussaint  \
# 336         76986.0       0       0       0                         0
# 337         75624.0       0       0       0                         0
# 338         73317.0       0       0       0                         0
# 339         74096.0       0       0       0                         0
# 340         73854.0       0       0       0                         0
# ...             ...     ...     ...     ...                       ...
# 70123       63946.0       0       0       0                         0
# 70124       63063.0       0       0       0                         0
# 70125       63816.0       0       0       0                         0
# 70126       65437.0       0       0       0                         0
# 70127       65159.0       0       0       0                         0
#
#        Vacances de Noël  Vacances d'Hiver  Vacances de Printemps  \
# ...
